# %%
import pandas as pd
import numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import linReg as lr

# %%
train = pd.read_csv('./Data/train.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
plt.scatter(train['LotArea'],train['SalePrice']);

# %%
plt.scatter(train['YearBuilt'],train['SalePrice']);

# %%
plt.scatter(train['TotalBsmtSF'],train['SalePrice']);

# %%
plt.scatter(train['BsmtFinSF1'],train['SalePrice']);

# %%
plt.scatter(train['GarageArea'],train['SalePrice']);

# %%
plt.scatter(train['TotRmsAbvGrd'],train['SalePrice']);

# %%
plt.scatter(train['LotFrontage'],train['SalePrice']);

# %% [markdown]
# We started by created scatter plots to see which one we would like to use in our model. We decided on that one because by eyesight it has a decent correlation. Then we created a module for our code which is LinReg. We did have some issues creating the code, but I believe it should be all set now. The issue is that it will take a while for the code to run and because we were fixing it to the last minute I was unable to create any graphs from the code. With that being said the output should be the count, loss, newLoss, WB which we can then put it into the regression formula.

# %%
temp = lr.minLossCalc(14,5000,train['LotArea'],train['SalePrice'])
temp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-69a320e5df76> in <module>()
# ----> 1 temp = lr.minLossCalc(14,5000,train['LotArea'],train['SalePrice'])
#       2 temp
#
# ~\Documents\CIS512\Project1\linReg.py in minLossCalc(w, b, x, y)
#       8     WB = numpy.array([[w], [b]], dtype=int)
#       9     N = len(x)
# ---> 10     return type(X.value)
#      11
#      12     loss = 1
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value'

# %% [markdown]
# -4336122479073758121
# 30351951136810 -9223372036854775807
